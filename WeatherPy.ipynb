# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | panaba
# Processing Record 2 of Set 1 | glendive
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | akdagmadeni
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | san quintin
# Processing Record 10 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 11 of Set 1 | muros
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | walvis bay
# Processing Record 14 of Set 1 | katsuura
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | lufilufi
# Processing Record 18 of Set 1 | iquitos
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | sitka
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | ostrovnoy
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | zyryanka
# Processing Record 30 of Set 1 | muzhi
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | madang
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | leh
# Processing Record 36 of Set 1 | luwuk
# Processing Record 37 of Set 1 | ambon
# Processing Record 38 of Set 1 | entre rios
# Processing Record 39 of Set 1 | ahipara
# Processing Record 40 of Set 1 | fort nelson
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | luderitz
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | guerrero negro
# Processing Record 49 of Set 1 | kourou
# Processing Record 50 of Set 1 | beaverlodge
# Processing Record 0 of Set 2 | mataura
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | whitianga
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | tocopilla
# Processing Record 8 of Set 2 | lusaka
# Processing Record 9 of Set 2 | kazbegi
# City not found. Skipping...
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 2 | port hardy
# Processing Record 13 of Set 2 | nadym
# Processing Record 14 of Set 2 | sorong
# Processing Record 15 of Set 2 | atambua
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | ferkessedougou
# Processing Record 18 of Set 2 | ituango
# Processing Record 19 of Set 2 | turukhansk
# Processing Record 20 of Set 2 | caravelas
# Processing Record 21 of Set 2 | rocha
# Processing Record 22 of Set 2 | grand gaube
# Processing Record 23 of Set 2 | makung
# City not found. Skipping...
# Processing Record 24 of Set 2 | moree
# Processing Record 25 of Set 2 | altay
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | tiznit
# Processing Record 31 of Set 2 | taywarah
# Processing Record 32 of Set 2 | kudahuvadhoo
# Processing Record 33 of Set 2 | youkounkoun
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | kapit
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | jinka
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | kovernino
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | amarante do maranhao
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 0 of Set 3 | port elizabeth
# Processing Record 1 of Set 3 | rio grande
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | plettenberg bay
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | blackwater
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | kefamenanu
# Processing Record 9 of Set 3 | bellevue
# Processing Record 10 of Set 3 | nouakchott
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 3 | cururupu
# Processing Record 14 of Set 3 | kabardinka
# Processing Record 15 of Set 3 | tautira
# Processing Record 16 of Set 3 | zeya
# Processing Record 17 of Set 3 | tahoua
# Processing Record 18 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 19 of Set 3 | isangel
# Processing Record 20 of Set 3 | papara
# Processing Record 21 of Set 3 | garissa
# Processing Record 22 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | kununurra
# Processing Record 29 of Set 3 | north bend
# Processing Record 30 of Set 3 | trani
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | saint combs
# City not found. Skipping...
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | la ronge
# Processing Record 35 of Set 3 | tandalti
# Processing Record 36 of Set 3 | tessalit
# Processing Record 37 of Set 3 | yuci
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | teluk nibung
# Processing Record 43 of Set 3 | bridlington
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | baculin
# Processing Record 47 of Set 3 | barcelona
# Processing Record 48 of Set 3 | koscian
# Processing Record 49 of Set 3 | codrington
# Processing Record 0 of Set 4 | hagen
# Processing Record 1 of Set 4 | port-gentil
# Processing Record 2 of Set 4 | balikpapan
# Processing Record 3 of Set 4 | fort stewart
# Processing Record 4 of Set 4 | arman
# Processing Record 5 of Set 4 | evanston
# Processing Record 6 of Set 4 | deputatskiy
# Processing Record 7 of Set 4 | alto araguaia
# Processing Record 8 of Set 4 | medicine hat
# Processing Record 9 of Set 4 | senanga
# Processing Record 10 of Set 4 | qostanay
# Processing Record 11 of Set 4 | kurilsk
# Processing Record 12 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | culpeper
# Processing Record 16 of Set 4 | khandbari
# Processing Record 17 of Set 4 | yelets
# Processing Record 18 of Set 4 | urucui
# Processing Record 19 of Set 4 | yerbogachen
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | belle glade
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | hilo
# Processing Record 24 of Set 4 | vanimo
# Processing Record 25 of Set 4 | leshan
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | dillon
# Processing Record 28 of Set 4 | saint peters
# Processing Record 29 of Set 4 | beibei
# Processing Record 30 of Set 4 | qurayyat
# Processing Record 31 of Set 4 | contamana
# Processing Record 32 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 4 | mulchen
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | nabire
# Processing Record 36 of Set 4 | leighton buzzard
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | buzmeyin
# Processing Record 39 of Set 4 | tuatapere
# Processing Record 40 of Set 4 | mandalgovi
# Processing Record 41 of Set 4 | morros
# Processing Record 42 of Set 4 | namatanai
# Processing Record 43 of Set 4 | camacha
# Processing Record 44 of Set 4 | lata
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | kaniama
# Processing Record 47 of Set 4 | bealanana
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | vredendal
# Processing Record 0 of Set 5 | arrigorriaga
# Processing Record 1 of Set 5 | lalmohan
# Processing Record 2 of Set 5 | la rioja
# Processing Record 3 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 5 | eyemouth
# Processing Record 5 of Set 5 | egvekinot
# Processing Record 6 of Set 5 | saint anthony
# Processing Record 7 of Set 5 | aden
# Processing Record 8 of Set 5 | nguruka
# Processing Record 9 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 5 | oranjemund
# Processing Record 11 of Set 5 | udachnyy
# Processing Record 12 of Set 5 | labuhan
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | barrow
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | misratah
# Processing Record 17 of Set 5 | praia
# Processing Record 18 of Set 5 | sibi
# Processing Record 19 of Set 5 | olavarria
# Processing Record 20 of Set 5 | eirunepe
# Processing Record 21 of Set 5 | pucallpa
# Processing Record 22 of Set 5 | cienfuegos
# Processing Record 23 of Set 5 | husavik
# Processing Record 24 of Set 5 | qaanaaq
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | saskylakh
# Processing Record 27 of Set 5 | imeni poliny osipenko
# Processing Record 28 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 5 | camana
# Processing Record 30 of Set 5 | dinghai
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | port blair
# Processing Record 33 of Set 5 | seoul
# Processing Record 34 of Set 5 | bilibino
# Processing Record 35 of Set 5 | chukhloma
# Processing Record 36 of Set 5 | takoradi
# Processing Record 37 of Set 5 | oktyabrskiy
# Processing Record 38 of Set 5 | portsmouth
# Processing Record 39 of Set 5 | wagar
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | djibo
# Processing Record 42 of Set 5 | lakatoro
# Processing Record 43 of Set 5 | kargasok
# Processing Record 44 of Set 5 | coihaique
# Processing Record 45 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 5 | cayeli
# Processing Record 47 of Set 5 | plouzane
# Processing Record 48 of Set 5 | blagoveshchenka
# Processing Record 49 of Set 5 | xining
# Processing Record 0 of Set 6 | sabang
# Processing Record 1 of Set 6 | harper
# Processing Record 2 of Set 6 | eureka
# Processing Record 3 of Set 6 | college
# Processing Record 4 of Set 6 | nuevo ideal
# Processing Record 5 of Set 6 | puri
# Processing Record 6 of Set 6 | alyangula
# Processing Record 7 of Set 6 | ribeira grande
# Processing Record 8 of Set 6 | hami
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | kitimat
# Processing Record 11 of Set 6 | pavlodolskaya
# Processing Record 12 of Set 6 | nelson bay
# Processing Record 13 of Set 6 | sao felix do xingu
# Processing Record 14 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 6 | yacuiba
# Processing Record 16 of Set 6 | port hedland
# Processing Record 17 of Set 6 | wilmington
# Processing Record 18 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | chabahar
# Processing Record 21 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 22 of Set 6 | potiskum
# Processing Record 23 of Set 6 | westport
# Processing Record 24 of Set 6 | los llanos de aridane
# Processing Record 25 of Set 6 | iracoubo
# Processing Record 26 of Set 6 | srednekolymsk
# Processing Record 27 of Set 6 | galveston
# Processing Record 28 of Set 6 | futtsu
# Processing Record 29 of Set 6 | lagoa
# Processing Record 30 of Set 6 | llandrindod wells
# Processing Record 31 of Set 6 | gamba
# Processing Record 32 of Set 6 | esso
# Processing Record 33 of Set 6 | buckeye
# Processing Record 34 of Set 6 | vestmanna
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | cochrane
# Processing Record 37 of Set 6 | hobyo
# Processing Record 38 of Set 6 | jalu
# Processing Record 39 of Set 6 | namibe
# Processing Record 40 of Set 6 | huarmey
# Processing Record 41 of Set 6 | okhotsk
# Processing Record 42 of Set 6 | nome
# Processing Record 43 of Set 6 | mackay
# Processing Record 44 of Set 6 | le locle
# Processing Record 45 of Set 6 | rabnita
# City not found. Skipping...
# Processing Record 46 of Set 6 | sechura
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | poum
# Processing Record 0 of Set 7 | quatre cocos
# Processing Record 1 of Set 7 | kutum
# Processing Record 2 of Set 7 | bergen
# Processing Record 3 of Set 7 | gusau
# Processing Record 4 of Set 7 | ossora
# Processing Record 5 of Set 7 | baghdad
# Processing Record 6 of Set 7 | fohnsdorf
# Processing Record 7 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 7 | zhigansk
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | chapais
# Processing Record 11 of Set 7 | bonthe
# Processing Record 12 of Set 7 | makaryev
# Processing Record 13 of Set 7 | sorland
# Processing Record 14 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 7 | alofi
# Processing Record 16 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 7 | berga
# Processing Record 18 of Set 7 | nanortalik
# Processing Record 19 of Set 7 | barentu
# Processing Record 20 of Set 7 | kahului
# Processing Record 21 of Set 7 | cherskiy
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | sitio novo do tocantins
# Processing Record 24 of Set 7 | maningrida
# Processing Record 25 of Set 7 | ngunguru
# Processing Record 26 of Set 7 | medea
# Processing Record 27 of Set 7 | pangnirtung
# Processing Record 28 of Set 7 | dwarka
# Processing Record 29 of Set 7 | betsiamites
# Processing Record 30 of Set 7 | whyalla
# Processing Record 31 of Set 7 | bairiki
# Processing Record 32 of Set 7 | bowen
# Processing Record 33 of Set 7 | brownsville
# Processing Record 34 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 7 | puerto varas
# Processing Record 36 of Set 7 | bada
# Processing Record 37 of Set 7 | tirumullaivasal
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | borujan
# City not found. Skipping...
# Processing Record 40 of Set 7 | turayf
# Processing Record 41 of Set 7 | necochea
# Processing Record 42 of Set 7 | kiunga
# Processing Record 43 of Set 7 | durazno
# Processing Record 44 of Set 7 | murchison
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | chachapoyas
# Processing Record 47 of Set 7 | slavsk
# Processing Record 48 of Set 7 | hurghada
# Processing Record 49 of Set 7 | tynda
# Processing Record 0 of Set 8 | havelock
# Processing Record 1 of Set 8 | tambovka
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | ust-omchug
# Processing Record 4 of Set 8 | kieta
# Processing Record 5 of Set 8 | gualaceo
# Processing Record 6 of Set 8 | sheikh dannun
# Processing Record 7 of Set 8 | tanout
# Processing Record 8 of Set 8 | dunedin
# Processing Record 9 of Set 8 | thinadhoo
# Processing Record 10 of Set 8 | alta floresta
# Processing Record 11 of Set 8 | pishin
# Processing Record 12 of Set 8 | santa rosa
# Processing Record 13 of Set 8 | elko
# Processing Record 14 of Set 8 | kaitangata
# Processing Record 15 of Set 8 | waiuku
# Processing Record 16 of Set 8 | vardo
# Processing Record 17 of Set 8 | vuktyl
# Processing Record 18 of Set 8 | sicamous
# Processing Record 19 of Set 8 | zurrieq
# Processing Record 20 of Set 8 | povoa de varzim
# Processing Record 21 of Set 8 | bambanglipuro
# Processing Record 22 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 23 of Set 8 | alor setar
# Processing Record 24 of Set 8 | sabinas hidalgo
# Processing Record 25 of Set 8 | pinega
# Processing Record 26 of Set 8 | asyut
# Processing Record 27 of Set 8 | poya
# Processing Record 28 of Set 8 | quelimane
# Processing Record 29 of Set 8 | east london
# Processing Record 30 of Set 8 | wamba
# Processing Record 31 of Set 8 | pierre
# Processing Record 32 of Set 8 | magdagachi
# Processing Record 33 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 34 of Set 8 | mahon
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 8 | urusha
# Processing Record 38 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | vila franca do campo
# Processing Record 41 of Set 8 | flagstaff
# Processing Record 42 of Set 8 | richards bay
# Processing Record 43 of Set 8 | hualmay
# Processing Record 44 of Set 8 | kirakira
# Processing Record 45 of Set 8 | cockburn town
# Processing Record 46 of Set 8 | isabela
# Processing Record 47 of Set 8 | rio gallegos
# Processing Record 48 of Set 8 | pacifica
# Processing Record 49 of Set 8 | lavrentiya
# Processing Record 0 of Set 9 | santa vitoria do palmar
# Processing Record 1 of Set 9 | sochaczew
# Processing Record 2 of Set 9 | haines junction
# Processing Record 3 of Set 9 | inhambane
# Processing Record 4 of Set 9 | cidreira
# Processing Record 5 of Set 9 | phonhong
# Processing Record 6 of Set 9 | faanui
# Processing Record 7 of Set 9 | talnakh
# Processing Record 8 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | rawlins
# Processing Record 10 of Set 9 | huescar
# Processing Record 11 of Set 9 | antofagasta
# Processing Record 12 of Set 9 | riedlingen
# Processing Record 13 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 9 | beberibe
# Processing Record 15 of Set 9 | invermere
# Processing Record 16 of Set 9 | kavaratti
# Processing Record 17 of Set 9 | zhob
# Processing Record 18 of Set 9 | obo
# Processing Record 19 of Set 9 | saldanha
# Processing Record 20 of Set 9 | shenjiamen
# Processing Record 21 of Set 9 | mount gambier
# Processing Record 22 of Set 9 | santa maria del oro
# Processing Record 23 of Set 9 | kasumigaura
# Processing Record 24 of Set 9 | hefei
# Processing Record 25 of Set 9 | beringovskiy
# Processing Record 26 of Set 9 | san cosme y damian
# Processing Record 27 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 28 of Set 9 | lasa
# Processing Record 29 of Set 9 | svetlogorsk
# Processing Record 30 of Set 9 | mehamn
# Processing Record 31 of Set 9 | sibu
# Processing Record 32 of Set 9 | samarai
# Processing Record 33 of Set 9 | kungurtug
# Processing Record 34 of Set 9 | podyuga
# Processing Record 35 of Set 9 | mitu
# Processing Record 36 of Set 9 | marawi
# Processing Record 37 of Set 9 | tual
# Processing Record 38 of Set 9 | malanje
# Processing Record 39 of Set 9 | mushie
# Processing Record 40 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 9 | waipawa
# Processing Record 43 of Set 9 | half moon bay
# Processing Record 44 of Set 9 | grand-lahou
# Processing Record 45 of Set 9 | penzance
# Processing Record 46 of Set 9 | bosaso
# Processing Record 47 of Set 9 | santa maria
# Processing Record 48 of Set 9 | san vicente
# Processing Record 49 of Set 9 | airai
# Processing Record 0 of Set 10 | matara
# Processing Record 1 of Set 10 | bikaner
# Processing Record 2 of Set 10 | salalah
# Processing Record 3 of Set 10 | nioro
# Processing Record 4 of Set 10 | central point
# Processing Record 5 of Set 10 | mairana
# Processing Record 6 of Set 10 | mount isa
# Processing Record 7 of Set 10 | keti bandar
# Processing Record 8 of Set 10 | babu
# Processing Record 9 of Set 10 | susuman
# Processing Record 10 of Set 10 | saint george
# Processing Record 11 of Set 10 | port macquarie
# Processing Record 12 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 10 | snezhnogorsk
# Processing Record 14 of Set 10 | manitouwadge
# Processing Record 15 of Set 10 | nishihara
# Processing Record 16 of Set 10 | bathsheba
# Processing Record 17 of Set 10 | cap malheureux
# Processing Record 18 of Set 10 | srandakan
# Processing Record 19 of Set 10 | pasni
# Processing Record 20 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 10 | xinyu
# Processing Record 22 of Set 10 | shimoda
# Processing Record 23 of Set 10 | kyra
# Processing Record 24 of Set 10 | touros
# Processing Record 25 of Set 10 | sao joao da barra
# Processing Record 26 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 27 of Set 10 | carballo
# Processing Record 28 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 10 | karratha
# Processing Record 30 of Set 10 | bandarbeyla
# Processing Record 31 of Set 10 | hovd
# Processing Record 32 of Set 10 | mezhova
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | madimba
# Processing Record 35 of Set 10 | batemans bay
# Processing Record 36 of Set 10 | vostok
# Processing Record 37 of Set 10 | yaan
# Processing Record 38 of Set 10 | shahreza
# Processing Record 39 of Set 10 | faya
# Processing Record 40 of Set 10 | iqaluit
# Processing Record 41 of Set 10 | port shepstone
# Processing Record 42 of Set 10 | guarapari
# Processing Record 43 of Set 10 | khasan
# Processing Record 44 of Set 10 | shihezi
# Processing Record 45 of Set 10 | aginskoye
# Processing Record 46 of Set 10 | divnomorskoye
# Processing Record 47 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 48 of Set 10 | san ramon
# Processing Record 49 of Set 10 | saint-joseph
# Processing Record 0 of Set 11 | benghazi
# Processing Record 1 of Set 11 | doliana
# Processing Record 2 of Set 11 | fortuna
# Processing Record 3 of Set 11 | greenville
# Processing Record 4 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 11 | tczew
# Processing Record 6 of Set 11 | goderich
# Processing Record 7 of Set 11 | bara
# Processing Record 8 of Set 11 | spetsai
# City not found. Skipping...
# Processing Record 9 of Set 11 | korla
# Processing Record 10 of Set 11 | maymanak
# City not found. Skipping...
# Processing Record 11 of Set 11 | hirara
# Processing Record 12 of Set 11 | jacqueville
# Processing Record 13 of Set 11 | luangwa
# Processing Record 14 of Set 11 | newport
# Processing Record 15 of Set 11 | lethem
# Processing Record 16 of Set 11 | devin
# Processing Record 17 of Set 11 | rawson
# Processing Record 18 of Set 11 | sunrise manor
# Processing Record 19 of Set 11 | xalpatlahuac
# Processing Record 20 of Set 11 | sechelt
# Processing Record 21 of Set 11 | pondicherry
# Processing Record 22 of Set 11 | inuvik
# Processing Record 23 of Set 11 | segovia
# Processing Record 24 of Set 11 | luleburgaz
# Processing Record 25 of Set 11 | atar
# Processing Record 26 of Set 11 | aykhal
# Processing Record 27 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 28 of Set 11 | moses lake
# Processing Record 29 of Set 11 | giyon
# Processing Record 30 of Set 11 | kaeo
# Processing Record 31 of Set 11 | adrar
# Processing Record 32 of Set 11 | tahta
# Processing Record 33 of Set 11 | analipsis
# Processing Record 34 of Set 11 | mana
# Processing Record 35 of Set 11 | mandera
# Processing Record 36 of Set 11 | ulaangom
# Processing Record 37 of Set 11 | asau
# Processing Record 38 of Set 11 | norfolk
# Processing Record 39 of Set 11 | kawalu
# Processing Record 40 of Set 11 | sisimiut
# Processing Record 41 of Set 11 | karangasem
# Processing Record 42 of Set 11 | manaus
# Processing Record 43 of Set 11 | pasighat
# Processing Record 44 of Set 11 | karatau
# Processing Record 45 of Set 11 | ewa beach
# Processing Record 46 of Set 11 | ballinrobe
# Processing Record 47 of Set 11 | sinnamary
# Processing Record 48 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 11 | biak
# Processing Record 0 of Set 12 | maracana
# Processing Record 1 of Set 12 | constitucion
# Processing Record 2 of Set 12 | flinders
# Processing Record 3 of Set 12 | awjilah
# Processing Record 4 of Set 12 | ifanadiana
# Processing Record 5 of Set 12 | batagay-alyta
# Processing Record 6 of Set 12 | sakakah
# Processing Record 7 of Set 12 | acajutla
# Processing Record 8 of Set 12 | pangai
# Processing Record 9 of Set 12 | makakilo city
# Processing Record 10 of Set 12 | sumkino
# Processing Record 11 of Set 12 | broken hill
# Processing Record 12 of Set 12 | victor harbor
# Processing Record 13 of Set 12 | elizabeth city
# Processing Record 14 of Set 12 | lebyazhye
# Processing Record 15 of Set 12 | urucuca
# Processing Record 16 of Set 12 | escanaba
# Processing Record 17 of Set 12 | chajul
# Processing Record 18 of Set 12 | bolivar
# Processing Record 19 of Set 12 | kalmunai
# Processing Record 20 of Set 12 | ribas do rio pardo
# Processing Record 21 of Set 12 | gombong
# Processing Record 22 of Set 12 | port moresby
# Processing Record 23 of Set 12 | lukh
# Processing Record 24 of Set 12 | fort frances
# Processing Record 25 of Set 12 | russell
# Processing Record 26 of Set 12 | honiara
# Processing Record 27 of Set 12 | diego de almagro
# Processing Record 28 of Set 12 | gold coast
# Processing Record 29 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 12 | ambulu
# Processing Record 31 of Set 12 | saint-pierre
# Processing Record 32 of Set 12 | green valley
# Processing Record 33 of Set 12 | matay
# Processing Record 34 of Set 12 | cape canaveral
# Processing Record 35 of Set 12 | tevriz
# Processing Record 36 of Set 12 | circleville
# Processing Record 37 of Set 12 | amiens
# Processing Record 38 of Set 12 | loviisa
# Processing Record 39 of Set 12 | kushiro
# Processing Record 40 of Set 12 | christchurch
# Processing Record 41 of Set 12 | saint-georges
# Processing Record 42 of Set 12 | zarate
# Processing Record 43 of Set 12 | lesnoy
# Processing Record 44 of Set 12 | malakal
# Processing Record 45 of Set 12 | maceio
# Processing Record 46 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 12 | saleaula
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          544
# Lat           544
# Lng           544
# Max Temp      544
# Humidity      544
# Cloudiness    544
# Wind Speed    544
# Country       544
# Date          544
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           panaba  21.2833  -88.2667    295.12        90           0
# 1         glendive  47.1053 -104.7125    275.09        80         100
# 2  arraial do cabo -22.9661  -42.0278    297.07        88          75
# 3         hermanus -34.4187   19.2345    293.04        82          69
# 4             sola -13.8833  167.5500    300.93        71          84
#
#    Wind Speed Country        Date
# 0        3.31      MX  1675910767
# 1        8.75      US  1675910768
# 2        2.06      BR  1675910770
# 3        5.68      ZA  1675910773
# 4        2.84      VU  1675910774

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude_values = city_data_df["Lat"]
temperature_values = city_data_df["Max Temp"]
Fig1 = plt.scatter(latitude_values, temperature_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output/Figure1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude_values = city_data_df["Lat"]
humidity_values = city_data_df["Humidity"]
Fig2 = plt.scatter(latitude_values, humidity_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output/Figure2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude_values = city_data_df["Lat"]
cloudiness_values = city_data_df["Cloudiness"]
Fig3 = plt.scatter(latitude_values, cloudiness_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output/Figure3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitude_values = city_data_df["Lat"]
wind_values = city_data_df["Wind Speed"]
Fig4 = plt.scatter(latitude_values, wind_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output/Figure4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x_values, y_values, title, x_label, y_label, text_coord):

    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    regress_values = x_values * slope + intercept

    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")

    plt.annotate(line_eq, text_coord, fontsize=15, color='red')

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    print(f"The r-value is: {r_value}")

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

Figure5 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Maximum Temperature on Northern Hemisphere",
                              "Latitude",
                              "Max Temperature (C)",
                              (10,-30))
# Out:
# The r-value is: -0.8462548186825359

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

Figure6 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Maximum Temperature on Southern Hemisphere",
                              "Latitude",
                              "Max Temperature (C)",
                              (-30,10))
# Out:
# The r-value is: 0.6419546065421794

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

Figure7 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Humidity on Northern Hemisphere",
                              "Latitude",
                              "Humidity (%)",
                              (40,20))
# Out:
# The r-value is: 0.23853179129394048

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]


Figure8 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Humidity on Southern Hemisphere",
                              "Latitude",
                              "Humidity (%)",
                              (-20,15))
# Out:
# The r-value is: 0.016759316950056783

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x-values and y-values for the plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function to plot the linear regression
Figure9 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Cloudiness on Northern Hemisphere",
                              "Latitude",
                              "Cloudiness (%)",
                              (30,45))
# Out:
# The r-value is: 0.15500489387697097

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

Figure10 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Cloudiness on Southern Hemisphere",
                              "Latitude",
                              "Cloudiness (%)",
                              (-45,45))
# Out:
# The r-value is: 0.14341322916643248

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

Figure11 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Wind Speed on Northern Hemisphere",
                              "Latitude",
                              "Wind Speed (m/s)",
                              (30,50))
# Out:
# The r-value is: 0.17434667290903338

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

Figure12 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Wind Speed on Southern Hemisphere",
                              "Latitude",
                              "Wind Speed (m/s)",
                              (-40,10))
# Out:
# The r-value is: -0.24947753546264592
